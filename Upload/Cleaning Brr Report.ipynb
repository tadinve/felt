# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('BrrPriorityReport2.csv')

# %%
df
# Out:
#      process_order_number  material_number  \
# 0                 3027274         10159237
# 1                 3079709         10161797
# 2                 3080581         10095576
# 3                 3080635         10110612
# 4                 3080688         10129627
# 5                 3080718         10159232
# 6                 3080755         10160545
# 7                 3080785         10161798
# 8                 3080791         10159253
# 9                 3080840         10168744
# 10                3081418         10159232
# 11                3081449         10095575
# 12                3081454         10095622
# 13                3081460         10095641
# 14                3081462         10095670
# 15                3081464         10095667
# 16                3081481         10107353
# 17                3081481         10107353
# 18                3081485         10107351
# 19                3081495         10109022
# 20                3081496         10110603
# ...

# %%
df1 = df.dropna()

# %%
df1.to_csv("BrrPriorityReportCleaned.csv", sep=',', encoding='utf-8')
